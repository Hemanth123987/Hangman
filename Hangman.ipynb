# %%
 import random
a =['DRIZZLING', 'ABOLISHED', 'MATHEMATICS','COSMOPOLITAN','DISINFORMATION','MISMANAGEMENTS','ANDHRAPRADESH','WATERMELON','MULTIMEDIA','EDUCATIONFAIR'] #list of words
b=random.choice(a) #selecting randomly one of the above words
#print(b) 
c=list(b) #converting into list
g=list(b) #also assignning to another variable
#print(len(c),"Correct word=",c)
i=0
while i<5:
    d=random.choice(c)
    if d!='_':
        #print(d)
        #print("Removed Letter",d)
        e=c.index(d)
        c[e]='_'
        i = i+1       
print("Finally The Resulted Word For Game ",c)
print("In The Above Missing Word Number of Missing Letters Are ",c.count("_"),"Try To Find Those")
from collections import Counter
c1 = Counter(g)
c2 = Counter(c)
h = c1-c2
#print ("Hint:You Have to Find",h)
count=0
while True:
    entry=input("please enter the letter")
    k=[index for index, value in enumerate(g) if value == entry]
    print(k)
    j=len(k)
    print(j)
    import itertools
    l = list(itertools.repeat(entry, j))
    print(l)
    from operator import setitem
    for n, o in zip(k, l):
        setitem(c, n, o)
    if entry  in h and c:
        print("It is There In h and c")
        print("IF_count",count)
    else:
        count=count+1
        print("else_count",count)
    print("count",count)
    c1 = Counter(g)
    c2 = Counter(c)
    h = c1-c2
    print("Updated h",h)
    if c==g:
        print("Congratulations ! Finally You Identified The Word")
        word= ''.join(c)
        print(word)
        break
    if count>5:
        print("We Are Sorry You Are Hanged and the word is ",''.join(g))
        break
    print("Updated Word",c)
    print("Original Word",g)
    print("You Have To Find Out The Remaining Of The Above Word In" , 6-count,"Attempts")

# %%
import random
a =['Hyderabad', 'Bangalore', 'Newdelhi','jammukashmir','Kanyakumari']
b=random.choice(a)
print(b) 
newstr = b.replace('a', '_')

newstr1 = newstr.replace('e', '_')
newstr2 = newstr1.replace('i', '_')
newstr3 = newstr2.replace('0', '_')
print(newstr3)

# %%
import random
a =['hyderabad', 'bangalore', 'newdelhi','jammukashmir','kanyakumari']
b=random.choice(a)
print(b)
c=list(b)
g=list(b)
print(len(c),c)
i=0
while i<5:
    d=random.choice(c)
    if d!='_':
        print(d)
        print("removing letter",d)
        e=c.index(d)
        c[e]='_'
        i = i+1
print("final list",c)
print("number of missing letters are ",c.count("_"),"are you ready to find those")
h = [item for item in g if item not in c]
print(h)
entry=input("please enter the letter")
while entry in g:
    f=g.indexall(entry)
    print(f)
    c[f]=entry
    print(c)
    entry=input("please enter the letter")
if entry in c[f]:
    
    
    
    
    
else:
    print("hello")

# %%
import random
a =['hyderabad', 'bangalore', 'newdelhi','jammukashmir','kanyakumari']
b=random.choice(a)
print(b)
c=list(b)
g=list(b)
print(len(c),c)
i=0
while i<5:
    d=random.choice(c)
    if d!='_':
        print(d)
        print("removing letter",d)
        e=c.index(d)
        c[e]='_'
        i = i+1
       
print("final list",c)
print("number of missing letters are ",c.count("_"),"are you ready to find those")
from collections import Counter
c1 = Counter(g)
c2 = Counter(c)
h = c1-c2
print (h)
entry=input("please enter the letter")
if entry in  (h,c):

    print(entry)
    
while entry in h:
        def indexall(lst, value):
             return [i for i, v in enumerate(lst) if v == value]

        k=indexall(g,entry)
        print(k)
        for ind in k:
            c[ind]=entry
            print(c)
            entry=input("please enter the letter")
if entry in  h not in  c :
    print(entry)
else:
    
    while entry in h:
        def indexall(lst, value):
             return [i for i, v in enumerate(lst) if v == value]

        k=indexall(g,entry)
        print(k)
        for ind in k:
            c[ind]=entry
            print(c)
            entry=input("please enter the letter")            
    
if entry in  c not in  h :
    print(entry)
else:
    
    while entry in h:
        def indexall(lst, value):
             return [i for i, v in enumerate(lst) if v == value]

        k=indexall(g,entry)
        print(k)
        for ind in k:
            c[ind]=entry
            print(c)
            entry=input("please enter the letter")     


word=

# %%
import random
a =['hyderabad', 'bangalore', 'newdelhi','jammukashmir','kanyakumari']
b=random.choice(a)
print(b)
c=list(b)
g=list(b)
print(len(c),"before=",c)
i=0
while i<5:
    d=random.choice(c)
    if d!='_':
        print(d)
        print("removing letter",d)
        e=c.index(d)
        c[e]='_'
        i = i+1
       
print("after",c)
print("number of missing letters are ",c.count("_"),"are you ready to find those")
from collections import Counter
c1 = Counter(g)
c2 = Counter(c)
h = c1-c2
print ("h",h)
count=0
while True:
     if int(count)>6:
        print("you are hanged")
        break
        entry=input("please enter the letter")
        k=[index for index, value in enumerate(g) if value == entry]
        print(k)
        j=len(k)
        print(j)
        count=count+1
        print(count)
        import itertools
        l = list(itertools.repeat(entry, j))
        print(l)
        from operator import setitem
        for n, o in zip(k, l):
            setitem(c, n, o)
            print(c)
        if c==g:
             print("you are done")
             break

# %%
 import random
#a =['DRIZZLING', 'ABOLISHED', 'MATHEMATICS','COSMOPOLITAN','DISINFORMATION','MISMANAGEMENTS','ANDHRAPRADESH','WATERMELON','MULTIMEDIA','EDUCATIONFAIR'] #list of words
a=['AAAAABBBB','AAAAABBBB']
b=random.choice(a) #selecting randomly one of the above words
#print(b) 
c=list(b) #converting into list
g=list(b) #also assignning to another variable
#print(len(c),"Correct word=",c)
i=0
while i<5:
    d=random.choice(c)
    if d!='_':
        #print(d)
        #print("Removed Letter",d)
        e=c.index(d)
        c[e]='_'
        i = i+1       
print("Finally The Resulted Word For Game ",c)
print("In The Above Missing Word Number of Missing Letters Are ",c.count("_"),"Try To Find Those")
from collections import Counter
c1 = Counter(g)
c2 = Counter(c)
h = c1-c2
#print ("Hint:You Have to Find",h)
count=0
while True:
    entry=input("please enter the letter")
    k=[index for index, value in enumerate(g) if value == entry]
    #print(k)
    j=len(k)
    #print(j)
    import itertools
    l = list(itertools.repeat(entry, j))
    #print(l)
    from operator import setitem
    for n, o in zip(k, l):
        setitem(c, n, o)
    if entry  in h and c:
        print("It is There In h and c")
        print("IF_count",count)
    else:
        count=count+1
        print("else_count",count)
    print("count",count)
    c1 = Counter(g)
    c2 = Counter(c)
    h = c1-c2
    #print("Updated h",h)
    if c==g:
        print("Congratulations ! Finally You Identified The Word")
        word= ''.join(c)
        print(word)
        break
    if count>5:
        print("We Are Sorry You Are Hanged and the word is ",''.join(g))
        break
    print("Updated Word",c)
   # print("Original Word",g)
    print("You Have To Find Out The Remaining Of The Above Word In" , 6-count,"Attempts")

# %%
if entry in  h not in  c :
    while entry in h:
        def indexall(lst, value):
             return [i for i, v in enumerate(lst) if v == value]

        k=indexall(g,entry)
        print(k)
        for ind in k:
            c[ind]=entry
            print(c)
            entry=input("please enter the letter")            
    
if entry in  c not in  h :
    while entry in h:
        def indexall(lst, value):
             return [i for i, v in enumerate(lst) if v == value]

        k=indexall(g,entry)
        print(k)
        for ind in k:
            c[ind]=entry
            print(c)
            entry=input("please enter the letter")
            
            
            
from operator import setitem
a = [5, 4, 3, 2, 1, 0]=c
ell = [0, 1, 3, 5]=k
m = [0, 0, 0, 0]=l
for n, o in zip(ell, l):
    setitem(a, n, o)
>>> a
[0, 0, 3, 0, 1, 0]

# %%
from operator import setitem
a = [5, 4, 3, 2, 1, 0]
ell = [0, 1, 3, 5]
m = [0, 0, 0, 0]
for n, o in zip(ell, l):
    setitem(a, n, o)
>>> a
[0, 0, 3, 0, 1, 0]

# %%
from matplotlib import pyplot as plt
plt.plot([1,2,3],[4,5,1])
plt.show()

# %%
# WOR
import random
a =['JAMMUKASHMIR', 'TAMILNADU', 'MAHARASHTRA','WESTBENGAL','UTTARPRADESH','ARUNACHALPRADESH','ANDHRAPRADESH'] #list of words
b=random.choice(a) #selecting randomly one of the above words
#print(b) 
c=list(b) #converting into list
g=list(b)#also assignning to another variable for further use in loop
print("Original WOrd",g)
#print(len(c),"Correct word=",c)
i=0
while i<4:
    d=random.choice(c)
    if d!='_':
        #print(d)
        #print("Removed Letter",d)`
        e=c.index(d)
        c[e]='_'
        i = i+1       
print("Finally The Resulted Word For Game ",c)
print("In The Above Missing Word Number of Missing Letters Are ",c.count("_"),"Try To Find Those")
count=0
while True:
    from collections import Counter
    c1 = Counter(g)
    c2 = Counter(c)
    h = c1-c2
    print(h)
    entry=input("Please enter the letter------>")
    if entry in h:
        #print("This is First Loop")
        print("You entry is  correct")
        G=[]
        for index, value in enumerate(g):
            if value == entry:
                print(index)
                G.append(index)
                print(G)
    #G=[index for index, value in enumerate(g) if value == entry]
        print(" Indices of Your entry in the Original word are",G)
        C=[]
        for index, value in enumerate(c):
            if value == entry:
                print(index)
                C.append(index)
                print(C)
    #C=[index for index, value in enumerate(c) if value == entry]
        print(" Indices of Your entry in the Game word are",C)
        Diff=set(G)-set(C)
        print("Difference",Diff)
        w=list(Diff)
        print("list View",w)
        print("Inserting at w[0] ")
        c[w[0]]=entry
    if entry not in h:
        count=count+1
        print("You entry is  Incorrect")
    print("count",count)
    print("Updated Word",''.join(c))
    #print("Original Word",''.join(g))
    print("You Have To Find Out The Remaining Of The Above Word In" , 6-count,"Attempts")
    if c==g:
        print("Congratulations ! Finally You Identified The Word",''.join(c))
        break
    if count>5:
        print("We Are Sorry You Are Hanged and the word is ",''.join(g))
        break
# Out:
# Original WOrd ['W', 'E', 'S', 'T', 'B', 'E', 'N', 'G', 'A', 'L']
# Finally The Resulted Word For Game  ['W', 'E', '_', 'T', '_', 'E', 'N', '_', '_', 'L']
# In The Above Missing Word Number of Missing Letters Are  4 Try To Find Those
# Counter({'S': 1, 'B': 1, 'G': 1, 'A': 1})
# Please enter the letter------>g
# You entry is  Incorrect
# count 1
# Updated Word WE_T_EN__L
# You Have To Find Out The Remaining Of The Above Word In 5 Attempts
# Counter({'S': 1, 'B': 1, 'G': 1, 'A': 1})
# Please enter the letter------>s
# You entry is  Incorrect
# count 2
# Updated Word WE_T_EN__L
# You Have To Find Out The Remaining Of The Above Word In 4 Attempts
# Counter({'S': 1, 'B': 1, 'G': 1, 'A': 1})
# Please enter the letter------>S
# You entry is  correct
# 2
# [2]
#  Indices of Your entry in the Original word are [2]
#  Indices of Your entry in the Game word are []
# Difference {2}
# list View [2]
# Inserting at w[0]
# count 2
# Updated Word WEST_EN__L
# ...

# %%
A = ["A","B","C"]
set(A)
# Out:
# {'A', 'B', 'C'}

# %%
import random
a =['AAAABBBBCCCC', 'AAAAACCCCC'] 
b=random.choice(a) 
c=list(b)
k=[]
for index, value in enumerate(c):
    if value == 'A':
        print(index)
        k.append(index)
        print(k)

# %%
 import random
a =['DRIZZLING', 'ABOLISHED', 'MATHEMATICS','COSMOPOLITAN','DISINFORMATION','MISMANAGEMENTS','ANDHRAPRADESH','WATERMELON','MULTIMEDIA','EDUCATIONFAIR'] #list of words
b=random.choice(a) #selecting randomly one of the above words
#print(b) 
c=list(b) #converting into list
g=list(b)
print(g)#also assignning to another variable
#print(len(c),"Correct word=",c)
i=0
while i<4:
    d=random.choice(c)
    if d!='_':
        #print(d)
        #print("Removed Letter",d)
        e=c.index(d)
        c[e]='_'
        i = i+1       
print("Finally The Resulted Word For Game ",c)
print("In The Above Missing Word Number of Missing Letters Are ",c.count("_"),"Try To Find Those")
from collections import Counter
c1 = Counter(g)
c2 = Counter(c)
h = c1-c2
print ("Hint:You Have to Find",h)
count=0
while True:
    entry=input("please enter the letter")

# %%
data = [c, o, s, m, o, p, i, t]
for index, value in enumerate(data):
    if value ==o:
        print(index)

# %%
import random
a =['DRIZZLING', 'ABOLISHED', 'MATHEMATICS','COSMOPOLITAN','DISINFORMATION','MISMANAGEMENTS','ANDHRAPRADESH','WATERMELON','MULTIMEDIA','EDUCATIONFAIR'] #list of words
b=random.choice(a) #selecting randomly one of the above words
#print(b) 
c=list(b) #converting into list
g=list(b)
print(g)#also assignning to another variable
#print(len(c),"Correct word=",c)
i=0
while i<4:
    d=random.choice(c)
    if d!='_':
        #print(d)
        #print("Removed Letter",d)
        e=c.index(d)
        c[e]='_'
        i = i+1       
print("Finally The Resulted Word For Game ",c)
print("In The Above Missing Word Number of Missing Letters Are ",c.count("_"),"Try To Find Those")
from collections import Counter
c1 = Counter(g)
c2 = Counter(c)
h = c1-c2
print ("Hint:You Have to Find",h)
